# %%
calificacion = 86
conducta = 10

if calificacion >= 90:
    print("A")
    if conducta >= 9:
        print("Tu conducta es excelente")
elif calificacion >= 80:
    print("B")
elif calificacion >= 70:
    print("C")
elif calificacion >= 60:
    print("D")
else:
    print("E")
# Out:
# B

# %%
PL1 = not True
PL2 = False

print(PL1 or PL2)
# Out:
# False

# %%
edad = 55
tipo = "adulto_mayor"

es_mayor = edad >= 18
print(es_mayor)
aplica_descuento = (edad >= 60) and (tipo == "adulto_mayor")
print(aplica_descuento)
# Out:
# True
# False

# %%
edad = int(input("Ingresa tu edad"))

if(edad < 0):
    print("Aguanta, no hay edades menores a cero")
else:
    print("Ahora si vamos a trabajar con edades reales")
# Out:
# Ahora si vamos a trabajar con edades reales

# %%
precio = 30
if tipo == "adulto_mayor":
  descuento = precio * 0.12
elif tipo == "profesor" or tipo == "estudiante":
  descuento == precio * 0.10
else:
  descuento = 0
total = precio - descuento
print(f"saldo a pagar: $(total:.2f)")
# Out:
# saldo a pagar: $(total:.2f)

# %%
#Ejercicio 1
edad =int(input("Ingresa tu edad"))

if(edad < 18):
    print("Eres menor de edad")
else:
    print("Eres mayor de edad")
# Out:
# Eres mayor de edad

# %%
#Ejercicio 2
numero = int(input("Ingresa un numero entero"))

if(numero % 2 == 0):
    print("Es un numero par")
else:
    print("Es un numero impar")
# Out:
# Es un numero impar

# %%
#Ejercicio 3
calificacion = int(input("Ingresa la calificacion de 0 a 10"))

if (calificacion >= 6):
    print("Aprobaste")")
else:
    print("Literal reprobaste")
# Out:
# Literal reprobaste

# %%
#Ejercicio 4
edad = int(input("Ingresa tu edad porfavor"))

if edad <= 3:
    print("Eres un bebe")
elif edad >= 3 and edad <= 12:
    print("niño")
elif edad >= 13 and edad <= 17:
    print("adolescente")
else:
    print("adulto")
# Out:
# adulto

# %%
#Ejercicio 5
precio = 30
if tipo == "adulto_mayor":
  descuento = precio * 0.12
elif tipo == "profesor" or tipo == "estudiante":
  descuento == precio * 0.10
else:
  descuento = 0
total = precio - descuento
print(f"saldo a pagar: ${total:.2f}")
# Out:
# saldo a pagar: $26.40

# %%
#Ejercicio 6
edad = int(input("Ingresa tu edad"))
credencial = input("tienes credencial que sirvaaaaaaaaaaa?")
if edad >= 18 and credencial == "si":
    print("Puedes pasar")
else:
    print("No pasas")
# Out:
# Puedes pasar

# %%
#Ejercicio 7
numero1 = int(input("Ingresa el primer numero"))
numero2 = int(input("Ingresa el segundo numero"))

if numero1 or numero2 < 0:
    print("Hay un numero negativo")
else:
    print("todo bien")
# Out:
# Hay un numero negativo

# %%
#Ejercicio 8
numero = int(input("Ingresa numero entero"))
if numero > 0:
    print("es positivo")
if (numero % 2 == 0):
    print("Es un numero par")
else:
    print("el numero es impar")
# Out:
# es positivo
# Es un numero par

# %%
#Ejercicio 9
pregunta = input("quieres continuar? (si/no)")
if pregunta == "si" or pregunta == "no":
    print("Respuesta valida")
if not (pregunta == "si"):
    print("Proceso finalizado")
# Out:
# Respuesta valida
# Proceso finalizado

# %%
# BLOQUE 2

# %%
#Ejercicio 10
Contador = 1

while Contador <= 5:
    print(f"el contador es {Contador}")
    Contador += 1
# Out:
# el contador es 1
# el contador es 2
# el contador es 3
# el contador es 4
# el contador es 5

# %%
#Ejercicio 11
numero = int(input("Dame un numero entero positivo N"))
contador = 1
while numero <= 5:
    resultado = numero + contador
    numero = numero + 1
    print(f"la suma del 1 al 5 es: {numero}")
# Out:
# la suma del 1 al 5 es: 6

# %%
#Ejercicio 12
numero = int(input("Ingresa un numero entero"))
contador = 1
while contador <= 10:
    resultado = numero * contador
    print(f"{numero} * {contador} = {resultado}")
    contador += 1
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %%
#Ejercicio 13
contador = 5
while contador >= 1:
    print(f"{contador}")
    contador -= 1
print("Despegue")
# Out:
# 5
# 4
# 3
# 2
# 1
# Despegue

# %%
#Ejercicio 14
while True:
    texto = input("Ingresa algun texto:")
    if texto == "salir":
        print("fin ciclo")
        break
    print("el texto ingresado es:", texto)
# Out:
# el texto ingresado es:
# el texto ingresado es: hola
# el texto ingresado es: mundo
